# %%
# superposition.ipynb

# Cell 1 - Check qiskit install

import matplotlib.pyplot as plt
import numpy as np
import qiskit
from IPython.display import Math
from qiskit import Aer, QuantumCircuit, assemble, execute
from qiskit.quantum_info import Statevector
from qiskit.visualization import (
    array_to_latex,
    plot_bloch_multivector,
    plot_histogram,
    plot_state_qsphere,
)

for module, version in qiskit.__qiskit_version__.items():
    print(module, ":", version)
# Out:
# qiskit-terra : 0.20.2
# qiskit-aer : 0.10.4
# qiskit-ignis : 0.7.1
# qiskit-ibmq-provider : 0.19.1
# qiskit-aqua : None
# qiskit : 0.36.2
# qiskit-nature : 0.3.2
# qiskit-finance : 0.3.1
# qiskit-optimization : 0.3.2
# qiskit-machine-learning : 0.4.0

# %%
# Cell 2 - One qubit circuit on basis (single shot)

# Select a quantum computer to use
backend = Aer.get_backend("aer_simulator")

# Create a new circuit with one qubit
qc = QuantumCircuit(1)

# Initialize the qubit to a 1 state
qc.initialize([0, 1], 0)
# Save the current state vector so that we can call it later on
# "sv1" is the label that we will call
qc.save_statevector("sv1")

# Apply a NOT gate (Pauli X gate)
qc.x(0)

# Save the final state
# Final state vector does not need a label to be called
qc.save_statevector()

# Now run the circuit on the device
# shots denotes how many times we want to run the circuit
# .result() tells the program to pull only the results 
result = execute(qc, backend, shots=1).result()
counts = result.get_counts()

# Get the state vectors
sv1 = result.data(0)["sv1"]
# Syntax for last state vector
sv2 = result.get_statevector()

# This syntax uses matplotlib (mpl) to draw the circuit for us
display(qc.draw(output="mpl", scale=1.5))

display(array_to_latex(sv1, prefix="\\text{Statevector 1} = "))
# Draws the Bloch Sphere
display(plot_bloch_multivector(sv1))

display(array_to_latex(sv2, prefix="\\text{Statevector 2} = "))
display(plot_bloch_multivector(sv2))
# Out:
# $$
# \text{Statevector 1} =
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$
# $$
# \text{Statevector 2} =
# \begin{bmatrix}
# 1 & 0  \\
#  \end{bmatrix}
# $$

# %%
# Cell 3 - One qubit circuit not on basis (single shot)

backend = Aer.get_backend("aer_simulator")

qc = QuantumCircuit(1)

# Initializing as some sort of superposition
qc.initialize([0.5, np.sqrt(3) / 2], 0)
qc.save_statevector("sv1")

qc.x(0)
qc.save_statevector()

result = execute(qc, backend, shots=1).result()
counts = result.get_counts()

sv1 = result.data(0)["sv1"]
sv2 = result.get_statevector()

display(qc.draw(output="mpl", scale=1.5))

display(array_to_latex(sv1, prefix="\\text{Statevector 1} = "))
display(plot_bloch_multivector(sv1))

display(array_to_latex(sv2, prefix="\\text{Statevector 2} = "))
display(plot_bloch_multivector(sv2))

# Plotting the probabilities of the final state vector being a one or zero
plot_histogram(counts)
# Out:
# $$
# \text{Statevector 1} =
# \begin{bmatrix}
# \tfrac{1}{2} & \sqrt{\tfrac{3}{4}}  \\
#  \end{bmatrix}
# $$
# $$
# \text{Statevector 2} =
# \begin{bmatrix}
# \sqrt{\tfrac{3}{4}} & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
# Cell 4 - One qubit circuit not on basis (a few shots)

backend = Aer.get_backend("aer_simulator")

qc = QuantumCircuit(1)
# Third value assigns the quibit to an initial state
# If not included then python assumes 0 or north
qc.initialize([0.5, np.sqrt(3) / 2], 0)
qc.x(0)

qc.measure_all()

result = execute(qc, backend, shots=10).result()
counts = result.get_counts()

display(qc.draw(output="mpl", scale=1.5))

plot_histogram(counts)

# %%
# Cell 5 - One qubit circuit not on basis (multiple shots)

backend = Aer.get_backend("aer_simulator")

qc = QuantumCircuit(1)
qc.initialize([0.5, np.sqrt(3) / 2], 0)
qc.x(0)

qc.measure_all()

# Now running 10,000 times
# This allows for increased precision of probabilities
result = execute(qc, backend, shots=10_000).result()
counts = result.get_counts()

plot_histogram(counts)

# %%
# Cell 6 - One Pete Box (a single black ball)

backend = Aer.get_backend("aer_simulator")

qc = QuantumCircuit(1)
# Initialized to south pole (Black ball)
qc.initialize([0, 1], 0)
qc.save_statevector("sv1")
# Applying a Hadamard gate, putting the qubit in 
# an exactly 50/50 superposition state
qc.h(0)
qc.save_statevector()

result = execute(qc, backend, shots=1).result()
counts = result.get_counts()

sv1 = result.data(0)["sv1"]
sv2 = result.get_statevector()

display(qc.draw(output="mpl", scale=1.5))

display(array_to_latex(sv1, prefix="\\text{Statevector 1} = "))
display(plot_bloch_multivector(sv1))

display(array_to_latex(sv2, prefix="\\text{Statevector 2} = "))
display(plot_bloch_multivector(sv2))

plot_histogram(counts)
# Out:
# $$
# \text{Statevector 1} =
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$
# $$
# \text{Statevector 2} =
# \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} & -\tfrac{1}{\sqrt{2}}  \\
#  \end{bmatrix}
# $$

# %%
# Cell 7 - Two Pete Boxes (Single Black Ball)
# Note: This demonstrates the Hadamard Gate is Unitary
# Applying the gate twice will undo itself

backend = Aer.get_backend("aer_simulator")

qc = QuantumCircuit(1)
qc.initialize([0, 1], 0)
qc.save_statevector("sv1")
qc.h(0)
qc.save_statevector("sv2")
qc.h(0)
qc.save_statevector()

result = execute(qc, backend, shots=1).result()
counts = result.get_counts()

sv1 = result.data(0)["sv1"]
sv2 = result.data(0)["sv2"]
sv3 = result.get_statevector()

display(qc.draw(output="mpl", scale=1.5))

display(array_to_latex(sv1, prefix="\\text{Statevector 1} = "))
display(plot_bloch_multivector(sv1))

display(array_to_latex(sv2, prefix="\\text{Statevector 2} = "))
display(plot_bloch_multivector(sv2))

display(array_to_latex(sv3, prefix="\\text{Statevector 3} = "))
display(plot_bloch_multivector(sv3))

plot_histogram(counts)
# Out:
# $$
# \text{Statevector 1} =
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$
# $$
# \text{Statevector 2} =
# \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} & -\tfrac{1}{\sqrt{2}}  \\
#  \end{bmatrix}
# $$
# $$
# \text{Statevector 3} =
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$

# %%
# Cell 8 - Gate Equivalence
# This demonstrates the identity X = HZH

backend = Aer.get_backend("aer_simulator")

qc = QuantumCircuit(1)

qc.initialize([0, 1], 0)
qc.save_statevector("sv1")
qc.h(0)
qc.save_statevector("sv2")
qc.z(0)
qc.save_statevector("sv3")
qc.h(0)
qc.save_statevector()

result = execute(qc, backend, shots=1).result()
counts = result.get_counts()

sv1 = result.data(0)["sv1"]
sv2 = result.data(0)["sv2"]
sv3 = result.data(0)["sv3"]
sv4 = result.get_statevector()


display(qc.draw(output="mpl", scale=1.5))

display(array_to_latex(sv1, prefix="\\text{Statevector 1} = "))
display(plot_bloch_multivector(sv1))

display(array_to_latex(sv2, prefix="\\text{Statevector 2} = "))
display(plot_bloch_multivector(sv2))

display(array_to_latex(sv3, prefix="\\text{Statevector 3} = "))
display(plot_bloch_multivector(sv3))

display(array_to_latex(sv4, prefix="\\text{Statevector 4} = "))
display(plot_bloch_multivector(sv4))
# Out:
# $$
# \text{Statevector 1} =
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$
# $$
# \text{Statevector 2} =
# \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} & -\tfrac{1}{\sqrt{2}}  \\
#  \end{bmatrix}
# $$
# $$
# \text{Statevector 3} =
# \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} & \tfrac{1}{\sqrt{2}}  \\
#  \end{bmatrix}
# $$
# $$
# \text{Statevector 4} =
# \begin{bmatrix}
# 1 & 0  \\
#  \end{bmatrix}
# $$
